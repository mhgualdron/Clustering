# %% [markdown]
# # <span style= "color:Royalblue"><center> Curso de Clustering con Python y Scikit-learn</center></span>

# %%
from sklearn.datasets import make_blobs
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
from sklearn.cluster import KMeans

# %%
# %run "template_visualitation.ipynb"

# %%
x,y = make_blobs(n_samples=100, centers=4,n_features=2,
          cluster_std=[1,1.5,2,2],random_state=7)

# %%
df_blobs = pd.DataFrame({
    'x1':x[:,0],'x2':x[:,1],
    'y':y})
df_blobs
# Out:
#            x1        x2  y
# 0   -3.384261  5.221740  1
# 1   -1.836238 -7.735384  3
# 2   -7.456176  6.198874  0
# 3   -1.785043  1.609749  1
# 4  -10.124910  6.133805  0
# ..        ...       ... ..
# 95   7.072755 -0.259937  2
# 96  -2.626873 -7.228570  3
# 97  -1.521099  1.802284  1
# 98  -9.216388  6.670846  0
# 99  -1.681382  6.414631  1
#
# [100 rows x 3 columns]

# %%
def plot2d_clusters(x,y,ax):
    y_uniques = pd.Series(y).unique()
    for i in y_uniques:
        x[y==i].plot(
        title=f'{len(y_uniques)} Clusters',
        kind='scatter',
        x='x1',
        y='x2',
        marker=f'${i}$',
        ax = ax)

# %%
fig, ax = plt.subplots(1,1, figsize=(9,9))
x,y = df_blobs[['x1','x2']],df_blobs['y']
plot2d_clusters(x,y,ax)

# %%
kmeans = KMeans(n_clusters=4, random_state=7,n_init=10)

# %%
y_pred = kmeans.fit_predict(x)
# Out:
# C:\Users\Mateo\anaconda3\envs\data\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning:
#
# KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.

# %%
fig, ax = plt.subplots(1,2,figsize=(9,9))
plot2d_clusters(x,y,ax[0])
plot2d_clusters(x,y_pred,ax[1])
ax[0].set_title(f'Actual {ax[0].get_title()}')
ax[1].set_title(f'KMeans {ax[1].get_title()}')
# Out:
# Text(0.5, 1.0, 'KMeans 4 Clusters')

# %% [markdown]
# ### K-Means

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets

# %%
np.random.seed(137)
x = np.linspace(0,10)
m = float(1.8)
b = float(-0.2)
variacion = np.arange(0.1,0.3,0.05)
percentage = 0.2
y = m*x+b
n = np.random.normal(0, y.std(), y.size) * percentage
yn = y+n
fig = plt.figure()

ax1 = fig.add_subplot(111)
ax1.set_title(f'Gráfica $y = 1.8(x)-0.2$')
ax1.plot(x, y, label='Sin ruido',color='blue')
ax1.plot(x, yn, label=f'Con {percentage*100} % de ruido',
        marker='.',color='red')
plt.legend()

# %%
x = np.linspace(0,50)
m = float(1.8)
b = float(-0.2)
#noise = np.random.normal(0,1,size=(0,50))
y = m*x+b
